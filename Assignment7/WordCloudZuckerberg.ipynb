# %%
# Assignment 8(B): WordCloud on Mark Zukerberg text fileimport pandas as pd
from wordcloud import wordcloud
import nltk
from nltk import word_tokenize
import matplotlib.pyplot as pplt
from nltk.corpus import stopwords
# nltk.download('stopwords')

# %%
data = open("G:/College/Sl-VI DataSets/TextMining/MarkZukerberg.txt","r").read()
data = data.lower()

# %%
stop = stopwords.words('english')

# %%
def create_word_cloud(string):
    cloud = wordcloud.WordCloud(width=800,height=800,background_color = "white", stopwords = stop).generate(string)
    pplt.figure(figsize = (10, 10), facecolor = None)
    pplt.axis('off')
    pplt.imshow(cloud)

# %%
create_word_cloud(data)
